# %%
import numpy as np
import pandas as pd

# %%
# Shuffle and split data into train and test data
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
heart_csv_total = pd.read_csv("./Heart.csv")
heart_csv, heart_cst_test = split_train_test(heart_csv_total, 0.2)
print(len(heart_csv), "train +", len(heart_cst_test), "test")
# Out:
# 243 train + 60 test

# %%
heart_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 168 to 196
# Data columns (total 15 columns):
# Unnamed: 0    243 non-null int64
# Age           243 non-null int64
# Sex           243 non-null int64
# ChestPain     243 non-null object
# RestBP        243 non-null int64
# Chol          243 non-null int64
# Fbs           243 non-null int64
# RestECG       243 non-null int64
# MaxHR         243 non-null int64
# ExAng         243 non-null int64
# Oldpeak       243 non-null float64
# Slope         243 non-null int64
# Ca            240 non-null float64
# Thal          241 non-null object
# AHD           243 non-null object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 30.4+ KB

# %%
heart_csv.head()
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 168         169   35    1  asymptomatic     126   282    0        2    156
# 31           32   60    1  asymptomatic     117   230    1        0    160
# 136         137   70    1  asymptomatic     145   174    0        0    125
# 69           70   46    1    nonanginal     150   231    0        0    147
# 113         114   43    0  asymptomatic     132   341    1        2    136
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 168      1      0.0      1  0.0  reversable  Yes
# 31       1      1.4      1  2.0  reversable  Yes
# 136      1      2.6      3  0.0  reversable  Yes
# 69       0      3.6      2  0.0      normal  Yes
# 113      1      3.0      2  0.0  reversable  Yes

# %%
print(heart_csv['ChestPain'].value_counts(), end='\n\n')
print(heart_csv['Thal'].value_counts(), end='\n\n')
print(heart_csv['AHD'].value_counts(), end='\n\n')
# Out:
# asymptomatic    117
# nonanginal       67
# nontypical       39
# typical          20
# Name: ChestPain, dtype: int64
#
# normal        132
# reversable     94
# fixed          15
# Name: Thal, dtype: int64
#
# No     129
# Yes    114
# Name: AHD, dtype: int64

# %%
heart_csv.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean   150.580247   54.374486    0.703704  130.814815  245.539095    0.144033
# std     86.385671    9.049661    0.457566   17.057349   49.103550    0.351848
# min      1.000000   29.000000    0.000000   94.000000  131.000000    0.000000
# 25%     78.500000   48.000000    0.000000  120.000000  212.000000    0.000000
# 50%    152.000000   55.000000    1.000000  130.000000  240.000000    0.000000
# 75%    224.500000   61.000000    1.000000  140.000000  273.500000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  243.000000  243.000000  243.000000  243.000000  243.000000  240.000000
# mean     1.004115  148.123457    0.337449    1.006584    1.604938    0.679167
# ...

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["Age","RestBP", "Chol", "MaxHR", "Oldpeak"]
scatter_matrix(heart_csv[attributes], figsize=(12, 8))
# Out:
# /home/leleco/anaconda3/envs/tf_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b6395f2b0>,
# ...
#       dtype=object)
